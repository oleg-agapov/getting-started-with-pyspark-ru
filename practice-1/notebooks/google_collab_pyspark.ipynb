# %% [markdown]
# # Установка через pip

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/89/db/e18cfd78e408de957821ec5ca56de1250645b05f8523d169803d8df35a64/pyspark-3.1.2.tar.gz (212.4MB)
#      |████████████████████████████████| 212.4MB 58kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 16.4MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.1.2-py2.py3-none-any.whl size=212880768 sha256=67fcf8ed33f7e54c683eab66a80c1af6047dfd77287658513a18228c2ba31a94
#   Stored in directory: /root/.cache/pip/wheels/40/1b/2c/30f43be2627857ab80062bef1527c0128f7b4070b6b2d02139
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.1.2

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Test").getOrCreate()

# %%
spark.version
# Out:
# '3.1.2'

# %% [markdown]
# # Установка из исходников

# %% [markdown]
# Чуть более сложная установка и настройка, однако более гибкая (можно выбрать любую версию Spark и Java)

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.1.2/spark-3.1.2-bin-hadoop3.2.tgz
# !tar xf spark-3.1.2-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop3.2"

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
spark.version
# Out:
# '3.1.2'

# %% [markdown]
# # Дополнительные фишки

# %%
# Загрузка файла с локального диска

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-820b9486-fd24-4a44-ac30-1a3229e8480c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-820b9486-fd24-4a44-ac30-1a3229e8480c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# примонтировать Googel Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
